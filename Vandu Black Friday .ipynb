# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %%
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Astik'

# %%
os.chdir("C:\\VANDANA\\project\\black friday")

# %%
os.getcwd()
# Out:
# 'C:\\VANDANA\\project\\black friday'

# %%
train=pd.read_csv("blackfridaytrain.csv")
test=pd.read_csv("black friday test.csv")

# %%
train.shape
# Out:
# (550068, 12)

# %%
test.shape
# Out:
# (233599, 11)

# %%
train.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
test.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3
# 233594                 NaN                 NaN
# ...

# %%
blackfriday=train.append(test,ignore_index=True)

# %%
blackfriday.shape

# %%
blackfriday.head()

# %%
blackfriday.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 783662  1006036  P00118942      F  26-35          15             B
# 783663  1006036  P00254642      F  26-35          15             B
# 783664  1006036  P00031842      F  26-35          15             B
# 783665  1006037  P00124742      F  46-50           1             C
# 783666  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 783662                         4+               1                   8
# 783663                         4+               1                   5
# 783664                         4+               1                   1
# 783665                         4+               0                  10
# 783666                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase
# 783662                 NaN                 NaN       NaN
# ...

# %%
blackfriday.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
blackfriday.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
blackfriday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
sns.heatmap(blackfriday.corr(),annot=True,vmin=-1,vmax=1,center=0,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(blackfriday["Occupation"])
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Density'>

# %%
sns.distplot(blackfriday["Product_Category_1"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-0b1a100385d2> in <module>
# ----> 1 sns.distplot(blackfriday["Product_Category_1"])
#
# d:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2617     if kde:
#    2618         kde_color = kde_kws.pop("color", color)
# -> 2619         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#    2620         if kde_color != color:
#    2621             kde_kws["color"] = kde_color
#
# d:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.distplot(blackfriday["Product_Category_2"])
# Out:
# <AxesSubplot:xlabel='Product_Category_2', ylabel='Density'>

# %%
sns.distplot(blackfriday["Product_Category_3"])
# Out:
# <AxesSubplot:xlabel='Product_Category_3', ylabel='Density'>

# %%
sns.distplot(blackfriday["Purchase"])
# Out:
# <AxesSubplot:xlabel='Purchase', ylabel='Density'>

# %%
sns.boxplot(blackfriday["City_Category"],blackfriday["Occupation"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Occupation'>

# %%
sns.violinplot(blackfriday["City_Category"],blackfriday["Occupation"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Occupation'>

# %%
sns.boxplot(blackfriday["City_Category"],blackfriday["Product_Category_1"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_1'>

# %%
sns.violinplot(blackfriday["City_Category"],blackfriday["Product_Category_1"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_1'>

# %%
sns.boxplot(blackfriday["City_Category"],blackfriday["Product_Category_2"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_2'>

# %%
sns.violinplot(blackfriday["City_Category"],blackfriday["Product_Category_2"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_2'>

# %%
sns.boxplot(blackfriday["City_Category"],blackfriday["Product_Category_3"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_3'>

# %%
sns.violinplot(blackfriday["City_Category"],blackfriday["Product_Category_3"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_3'>

# %%
sns.violinplot(blackfriday["City_Category"],blackfriday["Purchase"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Purchase'>

# %%
sns.boxplot(blackfriday["City_Category"],blackfriday["Purchase"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Purchase'>

# %%
Gncount=blackfriday["Gender"].value_counts()
Gncount
# Out:
# M    590031
# F    193636
# Name: Gender, dtype: int64

# %%
Agcount=blackfriday["Age"].value_counts()
Agcount
# Out:
# 26-35    313015
# 36-45    156724
# 18-25    141953
# 46-50     65278
# 51-55     54784
# 55+       30579
# 0-17      21334
# Name: Age, dtype: int64

# %%
Gnlb=["M","F"]
plt.pie(Gncount,labels=Gnlb,autopct='%.0f%%')
plt.show()

# %%
sns.barplot(x=blackfriday["City_Category"],y=blackfriday["Occupation"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Occupation'>

# %%
sns.barplot(x=blackfriday["City_Category"],y=blackfriday["Product_Category_1"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_1'>

# %%
sns.barplot(x=blackfriday["City_Category"],y=blackfriday["Product_Category_2"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_2'>

# %%
sns.barplot(x=blackfriday["City_Category"],y=blackfriday["Product_Category_3"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Product_Category_3'>

# %%
sns.barplot(x=blackfriday["City_Category"],y=blackfriday["Purchase"])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='Purchase'>
